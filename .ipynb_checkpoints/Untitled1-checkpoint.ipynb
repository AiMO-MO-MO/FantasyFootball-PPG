# %%
from pathlib import Path
import pandas as pd

# %%
Complete = Path('CompleteDataSetWeekasStringANDFPTSasINT.csv')

# %%
CompleteDF = pd.read_csv(Complete)

# %%
CompleteDF.head()
# Out:
#    Unnamed: 0  Week              Name Position  Year     Game  Fantasy Points  \
# 0           0   1.0     Lamar Jackson       QB  2019  BAL@MIA              42
# 1           1   1.0      Dak Prescott       QB  2019  NYG@DAL              41
# 2           2   1.0    Deshaun Watson       QB  2019   HOU@NO              36
# 3           3   1.0  Matthew Stafford       QB  2019  DET@ARI              34
# 4           4   1.0       Case Keenum       QB  2019  WAS@PHI              33
#
#    PassingYards  PassingTDs  Ints  Rush Attempts  Rush Yards  Fumbles  \
# 0         324.0         5.0     0              3           6        0
# 1         405.0         4.0     0              4          12        0
# 2         268.0         3.0     1              4          40        0
# 3         385.0         3.0     0              3          22        1
# 4         380.0         3.0     0              0           0        0
#
#    RushTDs  Receptions  Receiving Yards  Receiving TDs
# ...

# %%
CompleteDF.drop('Unnamed: 0', axis=1, inplace=True)

# %%
CompleteDF.head()
# Out:
#    Week              Name Position  Year     Game  Fantasy Points  \
# 0   1.0     Lamar Jackson       QB  2019  BAL@MIA              42
# 1   1.0      Dak Prescott       QB  2019  NYG@DAL              41
# 2   1.0    Deshaun Watson       QB  2019   HOU@NO              36
# 3   1.0  Matthew Stafford       QB  2019  DET@ARI              34
# 4   1.0       Case Keenum       QB  2019  WAS@PHI              33
#
#    PassingYards  PassingTDs  Ints  Rush Attempts  Rush Yards  Fumbles  \
# 0         324.0         5.0     0              3           6        0
# 1         405.0         4.0     0              4          12        0
# 2         268.0         3.0     1              4          40        0
# 3         385.0         3.0     0              3          22        1
# 4         380.0         3.0     0              0           0        0
#
#    RushTDs  Receptions  Receiving Yards  Receiving TDs
# 0        0         NaN              NaN            NaN
# ...

# %%
CompleteDF['Week'] = CompleteDF['Week'].astype(str).str.rstrip('.0')

# %%
CompleteDF
# Out:
#       Week               Name Position  Year     Game  Fantasy Points  \
# 0        1      Lamar Jackson       QB  2019  BAL@MIA              42
# 1        1       Dak Prescott       QB  2019  NYG@DAL              41
# 2        1     Deshaun Watson       QB  2019   HOU@NO              36
# 3        1   Matthew Stafford       QB  2019  DET@ARI              34
# 4        1        Case Keenum       QB  2019  WAS@PHI              33
# ...    ...                ...      ...   ...      ...             ...
# 19974   17       Jaleel Scott       WR  2019  PIT@BAL               1
# 19975   17      Sammy Watkins       WR  2019   LAC@KC               1
# 19976   17        Chris Moore       WR  2019  PIT@BAL               0
# 19977   17    Diontae Spencer       WR  2019  OAK@DEN               0
# 19978   17  De'Anthony Thomas       WR  2019  PIT@BAL               0
#
#        PassingYards  PassingTDs  Ints  Rush Attempts  Rush Yards  Fumbles  \
# ...

# %%
CompleteDF = CompleteDF.rename(columns={'Fantasy Points': 'FantasyPoints', 'Rush Attempts': 'RushAttemps', 'Rush Yards': 'RushYards', 'Receiving Yards': 'ReceivingYards'})

# %%
CompleteDF
# Out:
#       Week               Name Position  Year     Game  FantasyPoints  \
# 0        1      Lamar Jackson       QB  2019  BAL@MIA             42
# 1        1       Dak Prescott       QB  2019  NYG@DAL             41
# 2        1     Deshaun Watson       QB  2019   HOU@NO             36
# 3        1   Matthew Stafford       QB  2019  DET@ARI             34
# 4        1        Case Keenum       QB  2019  WAS@PHI             33
# ...    ...                ...      ...   ...      ...            ...
# 19974   17       Jaleel Scott       WR  2019  PIT@BAL              1
# 19975   17      Sammy Watkins       WR  2019   LAC@KC              1
# 19976   17        Chris Moore       WR  2019  PIT@BAL              0
# 19977   17    Diontae Spencer       WR  2019  OAK@DEN              0
# 19978   17  De'Anthony Thomas       WR  2019  PIT@BAL              0
#
#        PassingYards  PassingTDs  Ints  RushAttemps  RushYards  Fumbles  \
# ...

# %%
CompleteDF.to_csv('FinalCompleteDataSet.csv')

# %%
CompleteDF
# Out:
#       Week               Name Position  Year     Game  FantasyPoints  \
# 0        1      Lamar Jackson       QB  2019  BAL@MIA             42
# 1        1       Dak Prescott       QB  2019  NYG@DAL             41
# 2        1     Deshaun Watson       QB  2019   HOU@NO             36
# 3        1   Matthew Stafford       QB  2019  DET@ARI             34
# 4        1        Case Keenum       QB  2019  WAS@PHI             33
# ...    ...                ...      ...   ...      ...            ...
# 19974   17       Jaleel Scott       WR  2019  PIT@BAL              1
# 19975   17      Sammy Watkins       WR  2019   LAC@KC              1
# 19976   17        Chris Moore       WR  2019  PIT@BAL              0
# 19977   17    Diontae Spencer       WR  2019  OAK@DEN              0
# 19978   17  De'Anthony Thomas       WR  2019  PIT@BAL              0
#
#        PassingYards  PassingTDs  Ints  RushAttemps  RushYards  Fumbles  \
# ...
